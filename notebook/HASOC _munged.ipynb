# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import collections
import numpy as np
import pandas as pd
import re
from argparse import Namespace
import nltk
from nltk.corpus import stopwords

# %%
args = Namespace(
    raw_dataset_csv="english_dataset.tsv",
    train_proportion=0.85,
    val_proportion=0.15,
    
    output_munged_csv="english_dataset_munged.tsv",
    seed=1337
)

# %%
df = pd.read_csv("english_dataset.tsv", sep="\\t", engine='python')

# %%
df.head()
# Out:
#       text_id                                               text  ... task_2 task_3
# 0  hasoc_en_1  #DhoniKeepsTheGlove | WATCH: Sports Minister K...  ...   NONE   NONE
# 1  hasoc_en_2  @politico No. We should remember very clearly ...  ...   HATE    TIN
# 2  hasoc_en_3  @cricketworldcup Guess who would be the winner...  ...   NONE   NONE
# 3  hasoc_en_4  Corbyn is too politically intellectual for #Bo...  ...   NONE   NONE
# 4  hasoc_en_5  All the best to #TeamIndia for another swimmin...  ...   NONE   NONE
#
# [5 rows x 5 columns]

# %%
set(df.task_1)
# Out:
# {'HOF', 'NOT'}

# %%
df_new = df[["text", "task_1"]]

# %%
by_category = collections.defaultdict(list)
for _, row in df_new.iterrows():
  by_category[row.task_1].append(row.to_dict())
print(by_category)
# Out:
# defaultdict(<class 'list'>, {'NOT': [{'text': "#DhoniKeepsTheGlove | WATCH: Sports Minister Kiren Rijiju issues statement backing MS Dhoni over 'Balidaan Badge', tells BCCI to take up the matter with ICC and keep government in the know as nation's pride is involved    https://t.co/zuo5335Rjr", 'task_1': 'NOT'}, {'text': '@cricketworldcup Guess who would be the winner of this #CWC19?     Team who gets maximum points from the abandoned matches 😄 #ShameOnICC #WIvsENG @ICC', 'task_1': 'NOT'}, {'text': "Corbyn is too politically intellectual for #BorisJohnsonShouldNotBePM   Can't wait   #GeneralElectionNow https://t.co/pt8KmjfxJj", 'task_1': 'NOT'}, {'text': 'All the best to #TeamIndia for another swimming competition on Sunday against #Pakistan.     #INDvPAK #ShameOnICC  #CWC19 #CWC19Rains ☔☔ https://t.co/MG2cIE0zib', 'task_1': 'NOT'}, {'text': '@kellymiller513 @TheRealOJ32 I hope you remembered to wipe the blood off of you, after the pic was taken.  #bloodonhishands #murderer', 'task_1': 'NOT'}, {'text': '@ICC Latest design of #WC2019 trophy. #CWC2019 #CWC19 #ShameOnICC https://t.co/g3mRuphBzE', 'task_1': 'NOT'}, {'text': 'Thanks for your support! Wow 600k. Graffiti has a massive impact nowadays, do not forget to show your own opinion!     #AllColorsAreBeautiful   #PowerToThePeople  #FuckRacism   #FuckTrump   #MakeLoveNotWar… https://t.co/4hc5UiDgLj', 'task_1': 'NOT'}, {'text': 'By wearing the #BalidaanBadge over his gloves @msdhoni has shown his love &amp; respect for the forces.     @icc should understand that this is not related to any political/religious/racial activities    This is about our #NationalPride    #DhoniKeepsTheGlove', 'task_1': 'NOT'}, {'text': "Mahendra Singh Dhoni's love for the Nation, Armed Forces and Soldiers has been intact which is truly commendable. He is Nation's Hero. No one represents our Country better than him. I stand with @msdhoni  #DhoniKeepsTheGlove #DhoniKeSaathDesh   #IndiaWithDhoni https://t.co/xFO4KNyj8b", 'task_1': 'NOT'}, {'text': '#ShameOnICC@ICC WINNER TEAM-RAIN  ICC RUN UP TEAM-RAIN  ICC MAN OF THE MATCH-RAIN  ICC MAN OF THE SERIES-RAIN  BEST BOWLER-RAIN  BEST WICKETKEPER-RAIN https://t.co/nEL5SXz6om', 'task_1': 'NOT'}, {'text': '@narendramodi  @pmoindia_namo  @narendramodi  @PMOIndia  @AmitShah  @RamNanthKobind  Grevious assault on jr doctors in all medical colleges in WB. No action being taken for safety security and justice. PM sir please intervene asap.  #Savethedoctors  #DoctorsFightBack', 'task_1': 'NOT'}, {'text': 'ICC denies request from BCCI to allow MSD wear gloves with Army insignia.    @ICC @BCCI #DhoniKeepTheGlove #DhoniKeepsTheGlove', 'task_1': 'NOT'}, {'text': "Wow, you're full of it @MattHancock   #BorisJohnsonShouldNotBePM   #KickThemOut https://t.co/mbl0wsYroj ", 'task_1': 'NOT'}, {'text': 'All Indian spectators shd hv #BalidanBadge in ground, #DhoniKeepsTheGlove #DhoniKeepBalidaanBadgeGlove #DhoniKeepsTheGlove #DhoniKeSathDesh', 'task_1': 'NOT'}, {'text': '@ICC  @BCCI  What about Virat Kholi tattoos 😂😂    #DhoniKeepsTheGlove https://t.co/hGaAB9GCyD', 'task_1': 'NOT'}, {'text': 'Which is more important?  #IndiaWithDhoni   #DhoniKeepsTheGlove https://t.co/Iib4R9P0qn', 'task_1': 'NOT'}, {'text': '@KBMteam @iowaspeedway @HBurtonRacing @rileyherbst @ToddGilliland_ @CSmithDrive @rileyherbst is gonna crash. #Douchebag', 'task_1': 'NOT'}, {'text': 'Harbor N Bay Mens Boxer Short Pack of 2 @ Rs.299    https://t.co/tceazILuQp    #DoctorsFightBack #SaveBengal #amazon #flipkart #deals #dealoftheday #amazingdeals #offers #discount #JaiShreeRam #ModiForAll', 'task_1': 'NOT'}, {'text': "ICC turns down #BCCI's request to allow @msdhoni to continue wearing the army insignia on his wicket-keeping gloves; ICC says regulations for ICC events do not permit any individual message or logo to be displayed on any items of clothing or equipment.   #DhoniKeepsTheGlove https://t.co/HuGm4DiLuL", 'task_1': 'NOT'}, {'text': 'Senior #Doctors of #RGKar greeted with applause &amp; ovation by #JuniorDoc ...

# %%
final_list = []
np.random.seed(args.seed)
for _, item_list in sorted(by_category.items()):
    np.random.shuffle(item_list)
    n = len(item_list)
    n_train = int(args.train_proportion*n)
    n_val = int(args.val_proportion*n)
    #n_test = int(args.test_proportion*n)
    
    # Give data point a split attribute
    for item in item_list[:n_train]:
        item['split'] = 'train'
    for item in item_list[n_train:n_train+n_val]:
        item['split'] = 'val'
    #for item in item_list[n_train+n_val:]:
        #item['split'] = 'test'  
    
    # Add to final list
    final_list.extend(item_list)

# %%
final_text = pd.DataFrame(final_list)

# %%
final_text.split.value_counts()
# Out:
# train    4975
# val       877
# Name: split, dtype: int64

# %%
def preprocess_text(text):
  
  text = re.sub("@[\w]*\b", " ", text)
  text = re.sub("[^a-zA-Z]", " ", text)  
  text = ' '.join(word.lower() for word in text.split(" ") if word not in nltk.corpus.stopwords.words('english'))
  return text

final_text.text = final_text.text.apply(preprocess_text)

# %%
final_text.text.head()
# Out:
# 0    guy longtime gop strategist  us already though...
# 1    dumbass chief dumbassery   fucktrump https   c...
# 2     amvetsupport stepped things integrity donald ...
# 3    seen rally yesterday      translation   leave ...
# 4     citynews  twitter think done quite enough alr...
# Name: text, dtype: object

# %%
vocab = (set(final_text.text))

# %%
len(vocab)
# Out:
# 5827

# %%
final_text.to_csv(args.output_munged_csv, index=False)
